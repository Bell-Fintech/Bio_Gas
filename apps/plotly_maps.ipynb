# %%
import pandas as pd
df=pd.read_excel('data.xlsx',sheet_name=None)#读取excel所有sheet数据
df
# Out:
# {'BGA 01_data sheet':     Unnamed: 0                                         Unnamed: 1  \
#  0          NaN                                             BGA 01
#  1          NaN                               General Information:
#  2          NaN                         installed electrical power
#  3          NaN                                       Installation
#  4          NaN                    Period of the measurement phase
#  5          NaN                                         Substrates
#  6          NaN                                    Gas utilization
#  7          NaN                          Receive flexibility bonus
#  8          NaN                                  Mode of operation
#  9          NaN                                                NaN
#  10         NaN                             Structural facilities:
#  11         NaN                                             Design
#  12         NaN                                             number
# ...

# %%
df.keys()
# Out:
# dict_keys(['BGA 01_data sheet', 'BGA 01_Diagrams', 'BGA 01_Economy', 'BGA 02_data sheet', 'BGA 02_Diagrams', 'BGA 02_Economy', 'BGA 03_data sheet', 'BGA 03_Diagrams', 'BGA 03_Economy', 'BGA 04_data sheet', 'BGA 04_Diagrams', 'BGA 04_Economy', 'BGA 05_data sheet', 'BGA 05_Diagrams', 'BGA 06_data sheet', 'BGA 06_Diagrams', 'BGA 06_Economy', 'BGA 07_data sheet', 'BGA 07_Diagrams', 'BGA 07_Economy', 'BGA 08_data sheet', 'BGA 08_Diagrams', 'BGA 08_Economy', 'BGA 09_data sheet', 'BGA 09_Diagrams', 'BGA 09_Economy', 'BGA 10_data sheet', 'BGA 10_Diagrams', 'BGA 10_Economy', 'BGA 11_data sheet', 'BGA 11_Diagrams', 'BGA 11_Economy', 'BGA 12_data sheet', 'BGA 12_Diagrams', 'BGA 12_Economy', 'BGA 13_data sheet', 'BGA 13_Diagrams', 'BGA 13_Economy', 'BGA 14_data sheet', 'BGA 14_Diagrams', 'BGA 14_Economy', 'BGA 15_data sheet', 'BGA 15_Diagrams', 'BGA15_Economy', 'BGA 16_data sheet', 'BGA16_Diagrams', 'BGA16_Economy', 'BGA 17_data sheet', 'BGA17_Diagrams', 'BGA 17_Economy', 'BGA 18_data sheet', 'B
# ...

# %%
df['BGA 01_Economy']
# Out:
#     Unnamed: 0                      Unnamed: 1  \
# 0          NaN                          BGA 01
# 1          NaN      installed electrical power
# 2          NaN  maximum rated electrical power
# 3          NaN                        Services
# 4          NaN                             NaN
# 5          NaN                             NaN
# 6          NaN                             NaN
# 7          NaN                             NaN
# 8          NaN                           Costs
# 9          NaN                             NaN
# 10         NaN                             NaN
# 11         NaN                             NaN
# 12         NaN                             NaN
# 13         NaN                             NaN
# 14         NaN                             NaN
# 15         NaN                             NaN
# 16         NaN                             NaN
# 17         NaN                             NaN
# 18         NaN                             NaN
# ...

# %%
df['BGA 01_Economy'].iloc[2,"Unameed：1"]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File D:\Program\anaconda3\envs\graduate\lib\site-packages\pandas\core\indexing.py:769, in _LocationIndexer._validate_tuple_indexer(self, key)
#     768 try:
# --> 769     self._validate_key(k, i)
#     770 except ValueError as err:
#
# File D:\Program\anaconda3\envs\graduate\lib\site-packages\pandas\core\indexing.py:1381, in _iLocIndexer._validate_key(self, key, axis)
#    1380 else:
# -> 1381     raise ValueError(f"Can only index by location with a [{self._valid_types}]")
#
# ValueError: Can only index by location with a [integer, integer slice (START point is INCLUDED, END point is EXCLUDED), listlike of integers, boolean array]
#
# The above exception was the direct cause of the following exception:
#
# ValueError                                Traceback (most recent call last)
# Input In [8], in <cell line: 1>()
# ...
